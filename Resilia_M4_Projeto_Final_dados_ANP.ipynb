# %% [markdown]
# <a href="https://colab.research.google.com/github/joaovictojuliao/Squad-2-M4/blob/solu%C3%A7%C3%A3o-perguntas-5%2C6-e-11/Resilia_M4_Projeto_Final_dados_ANP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. Importando os dados**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Importando a biblioteca Pandas e Matplotlib:
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Importando dados das regiões, estados e municípios
brasil_micro = pd.read_csv("/content/drive/MyDrive/Resilia - Módulo 4 - Projeto Final /CSV/Região, Estados e Municípios - 2022 - POR MÊS.csv")

# %%
#Convertendo para tipo float e alterando o separador decimal para ponto:
brasil_micro['PREÇO MÉDIO REVENDA'] = brasil_micro['PREÇO MÉDIO REVENDA'].str.replace(',','.').astype(float)
brasil_micro['DESVIO PADRÃO REVENDA'] = brasil_micro['DESVIO PADRÃO REVENDA'].str.replace(',','.').astype(float)
brasil_micro['PREÇO MÍNIMO REVENDA'] = brasil_micro['PREÇO MÍNIMO REVENDA'].str.replace(',','.').astype(float)
brasil_micro['PREÇO MÁXIMO REVENDA'] = brasil_micro['PREÇO MÁXIMO REVENDA'].str.replace(',','.').astype(float)
brasil_micro['COEF DE VARIAÇÃO REVENDA'] = brasil_micro['COEF DE VARIAÇÃO REVENDA'].str.replace(',','.').astype(float)

# %%
# Definindo a coluna 'PRODUTO' como novo índex:
brasil_micro = brasil_micro.set_index('PRODUTO')

# %%
#Visualizando resumo do dataframe original:
brasil_micro
# Out:
#                       MÊS        REGIÃO             ESTADO  \
# PRODUTO
# ETANOL HIDRATADO  jan.-22         NORTE               PARA
# ETANOL HIDRATADO  jan.-22       SUDESTE          SAO PAULO
# ETANOL HIDRATADO  jan.-22  CENTRO OESTE              GOIAS
# ETANOL HIDRATADO  jan.-22           SUL  RIO GRANDE DO SUL
# ETANOL HIDRATADO  jan.-22         NORTE               PARA
# ...                   ...           ...                ...
# OLEO DIESEL S10   ago.-22       SUDESTE     RIO DE JANEIRO
# OLEO DIESEL S10   ago.-22       SUDESTE          SAO PAULO
# OLEO DIESEL S10   ago.-22       SUDESTE          SAO PAULO
# OLEO DIESEL S10   ago.-22           SUL     SANTA CATARINA
# OLEO DIESEL S10   ago.-22         NORTE               PARA
#
#                               MUNICÍPIO  NÚMERO DE POSTOS PESQUISADOS  \
# PRODUTO
# ETANOL HIDRATADO             ABAETETUBA                             3
# ETANOL HIDRATADO             ADAMANTINA                            28
# ETANOL HIDRATADO  AGUAS LINDAS DE GOIAS                            24
# ETANOL HIDRATADO               ALEGRETE                            10
# ETANOL HIDRATADO               ALENQUER                             4
# ...                                 ...                           ...
# OLEO DIESEL S10           VOLTA REDONDA                            50
# OLEO DIESEL S10              VOTORANTIM                            37
# OLEO DIESEL S10             VOTUPORANGA                            55
# OLEO DIESEL S10                 XANXERE                            16
# OLEO DIESEL S10                XINGUARA                            37
#
#                  UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# PRODUTO
# ETANOL HIDRATADO              R$/l                5.969
# ETANOL HIDRATADO              R$/l                4.537
# ETANOL HIDRATADO              R$/l                5.198
# ETANOL HIDRATADO              R$/l                6.654
# ETANOL HIDRATADO              R$/l                7.120
# ...                            ...                  ...
# OLEO DIESEL S10               R$/l                7.430
# OLEO DIESEL S10               R$/l                7.030
# OLEO DIESEL S10               R$/l                7.210
# OLEO DIESEL S10               R$/l                7.090
# OLEO DIESEL S10               R$/l                7.420
#
#                   DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# PRODUTO
# ETANOL HIDRATADO                  0.000                 5.969
# ETANOL HIDRATADO                  0.088                 4.390
# ETANOL HIDRATADO                  0.116                 4.979
# ETANOL HIDRATADO                  0.488                 5.999
# ETANOL HIDRATADO                  0.000                 7.120
# ...                                 ...                   ...
# OLEO DIESEL S10                   0.269                 6.840
# OLEO DIESEL S10                   0.296                 6.550
# OLEO DIESEL S10                   0.279                 6.650
# OLEO DIESEL S10                   0.190                 6.730
# OLEO DIESEL S10                   0.657                 6.610
#
#                   PREÇO MÁXIMO REVENDA MARGEM MÉDIA REVENDA  \
# PRODUTO
# ETANOL HIDRATADO                 5.969                    -
# ETANOL HIDRATADO                 4.790                    -
# ETANOL HIDRATADO                 5.299                    -
# ETANOL HIDRATADO                 7.299                    -
# ETANOL HIDRATADO                 7.120                    -
# ...                                ...                  ...
# OLEO DIESEL S10                  7.990                    -
# OLEO DIESEL S10                  7.690                    -
# OLEO DIESEL S10                  7.690                    -
# OLEO DIESEL S10                  7.410                    -
# OLEO DIESEL S10                  8.850                    -
#
#                   COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# PRODUTO
# ETANOL HIDRATADO                     0.000                        -
# ETANOL HIDRATADO                     0.019                        -
# ETANOL HIDRATADO                     0.022                        -
# ETANOL HIDRATADO                     0.073                        -
# ETANOL HIDRATADO                     0.000                        -
# ...                                    ...                      ...
# OLEO DIESEL S10                      0.036                        -
# OLEO DIESEL S10                      0.042                        -
# OLEO DIESEL S10                      0.039                        -
# OLEO DIESEL S10                      0.027                        -
# OLEO DIESEL S10                      0.088                        -
#
#                  DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# PRODUTO
# ETANOL HIDRATADO                          -                         -
# ETANOL HIDRATADO                          -                         -
# ETANOL HIDRATADO                          -                         -
# ETANOL HIDRATADO                          -                         -
# ETANOL HIDRATADO                          -                         -
# ...                                     ...                       ...
# OLEO DIESEL S10                           -                         -
# OLEO DIESEL S10                           -                         -
# OLEO DIESEL S10                           -                         -
# OLEO DIESEL S10                           -                         -
# OLEO DIESEL S10                           -                         -
#
#                  PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO
# PRODUTO
# ETANOL HIDRATADO                         -                             -
# ETANOL HIDRATADO                         -                             -
# ETANOL HIDRATADO                         -                             -
# ETANOL HIDRATADO                         -                             -
# ETANOL HIDRATADO                         -                             -
# ...                                    ...                           ...
# OLEO DIESEL S10                          -                             -
# OLEO DIESEL S10                          -                             -
# OLEO DIESEL S10                          -                             -
# OLEO DIESEL S10                          -                             -
# OLEO DIESEL S10                          -                             -
#
# [21991 rows x 17 columns]

# %%
#Importando a planilha do Brasil como um todo:

brasil_macro = pd.read_csv("/content/drive/MyDrive/Resilia - Módulo 4 - Projeto Final /CSV/Brasil - 2013 até 2022 - POR MÊS.csv")

# %%
#Convertendo para tipo float e alterando o separador decimal  para ponto:
brasil_macro['PREÇO MÉDIO REVENDA'] = brasil_macro['PREÇO MÉDIO REVENDA'].str.replace(',','.').astype(float)
brasil_macro['DESVIO PADRÃO REVENDA'] = brasil_macro['DESVIO PADRÃO REVENDA'].str.replace(',','.').astype(float)
brasil_macro['PREÇO MÍNIMO REVENDA'] = brasil_macro['PREÇO MÍNIMO REVENDA'].str.replace(',','.').astype(float)
brasil_macro['PREÇO MÁXIMO REVENDA'] = brasil_macro['PREÇO MÁXIMO REVENDA'].str.replace(',','.').astype(float)
brasil_macro['COEF DE VARIAÇÃO REVENDA'] = brasil_macro['COEF DE VARIAÇÃO REVENDA'].str.replace(',','.').astype(float)

# %%
# Definindo a coluna 'PRODUTO' como novo índex:

brasil_macro = brasil_macro.set_index('PRODUTO')

# %%
#Visualizando o resumo do dataframe original:
brasil_macro
# Out:
#                         MÊS  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# PRODUTO
# ETANOL HIDRATADO    set.-21                         17403              R$/l
# GASOLINA ADITIVADA  set.-21                         14482              R$/l
# GASOLINA COMUM      set.-21                         19641              R$/l
# GLP                 set.-21                         14906           R$/13kg
# GNV                 set.-21                          1319             R$/m³
# ...                     ...                           ...               ...
# GASOLINA COMUM      ago.-22                         26424              R$/l
# GLP                 ago.-22                         19487           R$/13kg
# GNV                 ago.-22                          1889             R$/m³
# OLEO DIESEL         ago.-22                         11965              R$/l
# OLEO DIESEL S10     ago.-22                         22090              R$/l
#
#                     PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  \
# PRODUTO
# ETANOL HIDRATADO                  4.698                  0.502
# GASOLINA ADITIVADA                6.216                  0.349
# GASOLINA COMUM                    6.078                  0.349
# GLP                              97.736                  8.523
# GNV                               4.136                  0.431
# ...                                 ...                    ...
# GASOLINA COMUM                    5.390                  0.356
# GLP                             111.620                 10.381
# GNV                               5.050                  0.595
# OLEO DIESEL                       7.100                  0.379
# OLEO DIESEL S10                   7.190                  0.376
#
#                     PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# PRODUTO
# ETANOL HIDRATADO                   3.799                 7.199
# GASOLINA ADITIVADA                 5.099                 7.987
# GASOLINA COMUM                     5.049                 7.236
# GLP                               70.000               135.000
# GNV                                2.849                 5.799
# ...                                  ...                   ...
# GASOLINA COMUM                     4.130                 8.750
# GLP                               81.990               160.000
# GNV                                3.180                 6.890
# OLEO DIESEL                        6.240                 8.990
# OLEO DIESEL S10                    5.460                 9.000
#
#                    MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# PRODUTO
# ETANOL HIDRATADO                      -                     0.107
# GASOLINA ADITIVADA                    -                     0.056
# GASOLINA COMUM                        -                     0.057
# GLP                                   -                     0.087
# GNV                                   -                     0.104
# ...                                 ...                       ...
# GASOLINA COMUM                        -                     0.066
# GLP                                   -                     0.093
# GNV                                   -                     0.118
# OLEO DIESEL                           -                     0.053
# OLEO DIESEL S10                       -                     0.052
#
#                    PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# PRODUTO
# ETANOL HIDRATADO                          -                          -
# GASOLINA ADITIVADA                        -                          -
# GASOLINA COMUM                            -                          -
# GLP                                       -                          -
# GNV                                       -                          -
# ...                                     ...                        ...
# GASOLINA COMUM                            -                          -
# GLP                                       -                          -
# GNV                                       -                          -
# OLEO DIESEL                               -                          -
# OLEO DIESEL S10                           -                          -
#
#                    PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# PRODUTO
# ETANOL HIDRATADO                           -                         -
# GASOLINA ADITIVADA                         -                         -
# GASOLINA COMUM                             -                         -
# GLP                                        -                         -
# GNV                                        -                         -
# ...                                      ...                       ...
# GASOLINA COMUM                             -                         -
# GLP                                        -                         -
# GNV                                        -                         -
# OLEO DIESEL                                -                         -
# OLEO DIESEL S10                            -                         -
#
#                    COEF DE VARIAÇÃO DISTRIBUIÇÃO
# PRODUTO
# ETANOL HIDRATADO                               -
# GASOLINA ADITIVADA                             -
# GASOLINA COMUM                                 -
# GLP                                            -
# GNV                                            -
# ...                                          ...
# GASOLINA COMUM                                 -
# GLP                                            -
# GNV                                            -
# OLEO DIESEL                                    -
# OLEO DIESEL S10                                -
#
# [84 rows x 14 columns]

# %% [markdown]
# # **2. Limpando os dados: brasil_micro**

# %%
# Eliminando os combustíveis desnecessários para a análise:

brasil_micro.drop(["GLP", "GNV", "OLEO DIESEL", "OLEO DIESEL S10"], inplace=True)

# %%
#Eliminando as colunas desnecessárias para a análise:
brasil_micro.drop(["UNIDADE DE MEDIDA", "MARGEM MÉDIA REVENDA", "PREÇO MÉDIO DISTRIBUIÇÃO", "DESVIO PADRÃO DISTRIBUIÇÃO", "PREÇO MÍNIMO DISTRIBUIÇÃO", "PREÇO MÁXIMO DISTRIBUIÇÃO", "COEF DE VARIAÇÃO DISTRIBUIÇÃO"], axis=1, inplace=True)

# %%
#Filtrando apenas o período que queremos: julho e agosto de 2022

#Filtrando julho de 2022
brasil_micro_julho = brasil_micro[brasil_micro['MÊS'] == 'jul.-22']

#Filtrando agosto de 2022
brasil_micro_ago = brasil_micro[brasil_micro['MÊS'] == 'ago.-22']

#Fazendo a junção dos dois períodos (julho + agosto) em um único dataframe:
brasil_micro = pd.concat([brasil_micro_julho, brasil_micro_ago])

#Visualizando o novo dataframe:
brasil_micro
# Out:
#                       MÊS        REGIÃO          ESTADO  \
# PRODUTO
# ETANOL HIDRATADO  jul.-22         NORTE            PARA
# ETANOL HIDRATADO  jul.-22      NORDESTE        MARANHAO
# ETANOL HIDRATADO  jul.-22       SUDESTE       SAO PAULO
# ETANOL HIDRATADO  jul.-22  CENTRO OESTE           GOIAS
# ETANOL HIDRATADO  jul.-22      NORDESTE           BAHIA
# ...                   ...           ...             ...
# GASOLINA COMUM    ago.-22       SUDESTE  RIO DE JANEIRO
# GASOLINA COMUM    ago.-22       SUDESTE       SAO PAULO
# GASOLINA COMUM    ago.-22       SUDESTE       SAO PAULO
# GASOLINA COMUM    ago.-22           SUL  SANTA CATARINA
# GASOLINA COMUM    ago.-22         NORTE            PARA
#
#                               MUNICÍPIO  NÚMERO DE POSTOS PESQUISADOS  \
# PRODUTO
# ETANOL HIDRATADO             ABAETETUBA                             4
# ETANOL HIDRATADO             ACAILANDIA                            17
# ETANOL HIDRATADO             ADAMANTINA                            24
# ETANOL HIDRATADO  AGUAS LINDAS DE GOIAS                            18
# ETANOL HIDRATADO             ALAGOINHAS                            36
# ...                                 ...                           ...
# GASOLINA COMUM            VOLTA REDONDA                            55
# GASOLINA COMUM               VOTORANTIM                            49
# GASOLINA COMUM              VOTUPORANGA                            54
# GASOLINA COMUM                  XANXERE                            16
# GASOLINA COMUM                 XINGUARA                            40
#
#                   PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  \
# PRODUTO
# ETANOL HIDRATADO                 5.84                  0.266
# ETANOL HIDRATADO                 5.87                  0.379
# ETANOL HIDRATADO                 3.97                  0.214
# ETANOL HIDRATADO                 4.36                  0.235
# ETANOL HIDRATADO                 5.38                  0.369
# ...                               ...                    ...
# GASOLINA COMUM                   5.71                  0.148
# GASOLINA COMUM                   5.13                  0.276
# GASOLINA COMUM                   5.14                  0.273
# GASOLINA COMUM                   5.41                  0.152
# GASOLINA COMUM                   6.36                  0.141
#
#                   PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# PRODUTO
# ETANOL HIDRATADO                  5.49                  6.09
# ETANOL HIDRATADO                  4.99                  6.30
# ETANOL HIDRATADO                  3.71                  4.39
# ETANOL HIDRATADO                  3.99                  4.59
# ETANOL HIDRATADO                  4.89                  5.99
# ...                                ...                   ...
# GASOLINA COMUM                    5.44                  5.99
# GASOLINA COMUM                    4.67                  5.79
# GASOLINA COMUM                    4.61                  5.69
# GASOLINA COMUM                    5.25                  5.69
# GASOLINA COMUM                    6.13                  6.57
#
#                   COEF DE VARIAÇÃO REVENDA
# PRODUTO
# ETANOL HIDRATADO                     0.046
# ETANOL HIDRATADO                     0.065
# ETANOL HIDRATADO                     0.054
# ETANOL HIDRATADO                     0.054
# ETANOL HIDRATADO                     0.069
# ...                                    ...
# GASOLINA COMUM                       0.026
# GASOLINA COMUM                       0.054
# GASOLINA COMUM                       0.053
# GASOLINA COMUM                       0.028
# GASOLINA COMUM                       0.022
#
# [2737 rows x 10 columns]

# %%
#Conferindo nova quantidade de linhas, colunas e tipo de dados:
brasil_micro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2737 entries, ETANOL HIDRATADO to GASOLINA COMUM
# Data columns (total 10 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   MÊS                           2737 non-null   object
#  1   REGIÃO                        2737 non-null   object
#  2   ESTADO                        2737 non-null   object
#  3   MUNICÍPIO                     2737 non-null   object
#  4   NÚMERO DE POSTOS PESQUISADOS  2737 non-null   int64
#  5   PREÇO MÉDIO REVENDA           2737 non-null   float64
#  6   DESVIO PADRÃO REVENDA         2737 non-null   float64
#  7   PREÇO MÍNIMO REVENDA          2737 non-null   float64
#  8   PREÇO MÁXIMO REVENDA          2737 non-null   float64
#  9   COEF DE VARIAÇÃO REVENDA      2737 non-null   float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 235.2+ KB

# %% [markdown]
# #**3. Limpando os dados: brasil_macro**

# %%
# Eliminando os combustíveis desnessários para a análise:
brasil_macro.drop(["GLP", "GNV", "OLEO DIESEL", "OLEO DIESEL S10"], inplace=True)

# %%
# Eliminando as colunas desnecessárias para a análise:
brasil_macro.drop(["UNIDADE DE MEDIDA", "MARGEM MÉDIA REVENDA", "PREÇO MÉDIO DISTRIBUIÇÃO", "DESVIO PADRÃO DISTRIBUIÇÃO", "PREÇO MÍNIMO DISTRIBUIÇÃO", "PREÇO MÁXIMO DISTRIBUIÇÃO", "COEF DE VARIAÇÃO DISTRIBUIÇÃO"], axis=1, inplace=True)

# %%
#Eliminando os meses/anos desnecessários para a análise:

#Filtrando o período de julho:
brasil_macro_julho = brasil_macro[brasil_macro['MÊS'] == 'jul.-22']
#Filtrando o período de agosto:
brasil_macro_ago = brasil_macro[brasil_macro['MÊS'] == 'ago.-22']
#Fazendo a junção dos dois períodos em um único dataframe:
brasil_macro = pd.concat([brasil_macro_julho, brasil_macro_ago])

#Visualizando o novo dataframe:
brasil_macro
# Out:
#                         MÊS  NÚMERO DE POSTOS PESQUISADOS  \
# PRODUTO
# ETANOL HIDRATADO    jul.-22                         19372
# GASOLINA ADITIVADA  jul.-22                         16343
# GASOLINA COMUM      jul.-22                         21917
# ETANOL HIDRATADO    ago.-22                         23455
# GASOLINA ADITIVADA  ago.-22                         19665
# GASOLINA COMUM      ago.-22                         26424
#
#                     PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  \
# PRODUTO
# ETANOL HIDRATADO                   4.36                  0.737
# GASOLINA ADITIVADA                 6.19                  0.509
# GASOLINA COMUM                     6.05                  0.491
# ETANOL HIDRATADO                   3.95                  0.648
# GASOLINA ADITIVADA                 5.55                  0.381
# GASOLINA COMUM                     5.39                  0.356
#
#                     PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# PRODUTO
# ETANOL HIDRATADO                    3.39                  7.89
# GASOLINA ADITIVADA                  4.99                  9.28
# GASOLINA COMUM                      4.92                  8.52
# ETANOL HIDRATADO                    2.89                  7.19
# GASOLINA ADITIVADA                  4.13                  8.82
# GASOLINA COMUM                      4.13                  8.75
#
#                     COEF DE VARIAÇÃO REVENDA
# PRODUTO
# ETANOL HIDRATADO                       0.169
# GASOLINA ADITIVADA                     0.082
# GASOLINA COMUM                         0.081
# ETANOL HIDRATADO                       0.164
# GASOLINA ADITIVADA                     0.069
# GASOLINA COMUM                         0.066

# %%
#Conferindo nova quantidade de linhas, colunas e tipo de dados:
brasil_macro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, ETANOL HIDRATADO to GASOLINA COMUM
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   MÊS                           6 non-null      object
#  1   NÚMERO DE POSTOS PESQUISADOS  6 non-null      int64
#  2   PREÇO MÉDIO REVENDA           6 non-null      float64
#  3   DESVIO PADRÃO REVENDA         6 non-null      float64
#  4   PREÇO MÍNIMO REVENDA          6 non-null      float64
#  5   PREÇO MÁXIMO REVENDA          6 non-null      float64
#  6   COEF DE VARIAÇÃO REVENDA      6 non-null      float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 384.0+ bytes

# %% [markdown]
# # **4. Estatísticas descritivas**

# %% [markdown]
# * Aparentemente não há outliers
# * Não há valores nulos

# %%
#Principais estatísticas usando a função describe
brasil_micro.describe()
# Out:
#        NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# count                   2737.000000          2737.000000
# mean                      46.465473             5.496756
# std                       51.134987             0.782302
# min                        1.000000             3.360000
# 25%                       24.000000             5.140000
# 50%                       36.000000             5.620000
# 75%                       52.000000             6.030000
# max                      752.000000             7.730000
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# count            2737.000000           2737.000000           2737.000000
# mean                0.283299              5.057318              6.123935
# std                 0.136961              0.761368              0.963853
# min                 0.000000              2.890000              3.690000
# 25%                 0.186000              4.690000              5.590000
# 50%                 0.252000              5.190000              6.090000
# 75%                 0.359000              5.590000              6.840000
# max                 1.548000              7.690000              9.280000
#
#        COEF DE VARIAÇÃO REVENDA
# count               2737.000000
# mean                   0.051088
# std                    0.021501
# min                    0.000000
# 25%                    0.035000
# 50%                    0.048000
# 75%                    0.064000
# max                    0.230000

# %%
#Principais estatísticas usando a função describe
brasil_macro.describe()
# Out:
#        NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# count                       6.00000             6.000000
# mean                    21196.00000             5.248333
# std                      3526.39907             0.907225
# min                     16343.00000             3.950000
# 25%                     19445.25000             4.617500
# 50%                     20791.00000             5.470000
# 75%                     23070.50000             5.925000
# max                     26424.00000             6.190000
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# count               6.000000              6.000000              6.000000
# mean                0.520333              4.075000              8.408333
# std                 0.148762              0.828342              0.749864
# min                 0.356000              2.890000              7.190000
# 25%                 0.408500              3.575000              8.047500
# 50%                 0.500000              4.130000              8.635000
# 75%                 0.613250              4.722500              8.802500
# max                 0.737000              4.990000              9.280000
#
#        COEF DE VARIAÇÃO REVENDA
# count                  6.000000
# mean                   0.105167
# std                    0.047956
# min                    0.066000
# 25%                    0.072000
# 50%                    0.081500
# 75%                    0.143500
# max                    0.169000

# %%
#Histograma para verificar distribuição dos dados e se há presença de outliers para regiões, estados e municípios
brasil_micro.hist(bins=15, figsize=(15,15));

# %%
#Histograma para verificar distribuição dos dados e se há presença de outliers para regiões, estados e municípios
brasil_macro.hist(bins=15, figsize=(15,15));

# %% [markdown]
# # **5. Análise Exploratória**

# %% [markdown]
# **Pergunta 1: Como se comportaram o preço dos combustíveis durante os dois
# meses citados? Os valores do etanol e da gasolina tiveram uma de queda ou diminuição?**

# %%
brasil_micro_julho
brasil_micro_ago
brasil_macro_julho
brasil_macro_ago
# Out:
#                         MÊS  NÚMERO DE POSTOS PESQUISADOS  \
# PRODUTO
# ETANOL HIDRATADO    ago.-22                         23455
# GASOLINA ADITIVADA  ago.-22                         19665
# GASOLINA COMUM      ago.-22                         26424
#
#                     PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  \
# PRODUTO
# ETANOL HIDRATADO                   3.95                  0.648
# GASOLINA ADITIVADA                 5.55                  0.381
# GASOLINA COMUM                     5.39                  0.356
#
#                     PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# PRODUTO
# ETANOL HIDRATADO                    2.89                  7.19
# GASOLINA ADITIVADA                  4.13                  8.82
# GASOLINA COMUM                      4.13                  8.75
#
#                     COEF DE VARIAÇÃO REVENDA
# PRODUTO
# ETANOL HIDRATADO                       0.164
# GASOLINA ADITIVADA                     0.069
# GASOLINA COMUM                         0.066

# %%
.pyplot.show()

# %% [markdown]
# **Pergunta 2: Qual o preço médio da gasolina e do etanol nesses dois meses?**

# %%
#Para todas as regiões

pMedioGasolina = brasil_micro.loc['GASOLINA COMUM']
pMedioGasolinaA = brasil_micro.loc['GASOLINA ADITIVADA']
pMedioEtanol = brasil_micro.loc['ETANOL HIDRATADO']
print('O valor médio da gasolina nos 2 meses foi de :',pMedioGasolina['PREÇO MÉDIO REVENDA'].mean())
print('O valor médio da gasolina aditivada nos 2 meses foi de :',pMedioGasolinaA['PREÇO MÉDIO REVENDA'].mean())
print('O valor médio do etanol nos 2 meses foi de :',pMedioEtanol['PREÇO MÉDIO REVENDA'].mean())
# Out:
# O valor médio da gasolina nos 2 meses foi de : 5.789978213507625
# O valor médio da gasolina aditivada nos 2 meses foi de : 5.940131004366812
# O valor médio do etanol nos 2 meses foi de : 4.7489036544850505

# %% [markdown]
# **Pergunta 3: Quais os 5 estados com o preço médio da gasolina e do etanol mais caros?**
#
# Dentro dos meses de julho e agosto esses foram os estados com a maior média de valor de revenda em Gasolina Comum do Brasil:

# %%
round(brasil_micro.isnull().mean()*100,2) # verificando se existem valores nulos
# Out:
# MÊS                             0.0
# REGIÃO                          0.0
# ESTADO                          0.0
# MUNICÍPIO                       0.0
# NÚMERO DE POSTOS PESQUISADOS    0.0
# PREÇO MÉDIO REVENDA             0.0
# DESVIO PADRÃO REVENDA           0.0
# PREÇO MÍNIMO REVENDA            0.0
# PREÇO MÁXIMO REVENDA            0.0
# COEF DE VARIAÇÃO REVENDA        0.0
# dtype: float64

# %%
gasolina_comum = brasil_micro.loc['GASOLINA COMUM'] 
gasolina_comum.groupby(['ESTADO', 'PRODUTO'])[['PREÇO MÉDIO REVENDA']].mean().sort_values(['PREÇO MÉDIO REVENDA'], ascending = False).head()
# Out:
#                          PREÇO MÉDIO REVENDA
# ESTADO   PRODUTO
# AMAZONAS GASOLINA COMUM             6.492000
# ACRE     GASOLINA COMUM             6.445000
# CEARA    GASOLINA COMUM             6.227692
# PIAUI    GASOLINA COMUM             6.133750
# PARA     GASOLINA COMUM             6.133750

# %% [markdown]
# Dentro dos meses de julho e agosto esses foram os estados com a maior média de valor de revenda em Etanol Hidratado do Brasil:

# %%
etanol = brasil_micro.loc['ETANOL HIDRATADO'] 
etanol.groupby(['ESTADO', 'PRODUTO'])[['PREÇO MÉDIO REVENDA']].mean().sort_values(['PREÇO MÉDIO REVENDA'], ascending = False).head()
# Out:
#                                     PREÇO MÉDIO REVENDA
# ESTADO            PRODUTO
# AMAPA             ETANOL HIDRATADO             5.820000
# PARA              ETANOL HIDRATADO             5.742174
# CEARA             ETANOL HIDRATADO             5.731923
# RIO GRANDE DO SUL ETANOL HIDRATADO             5.701111
# RONDONIA          ETANOL HIDRATADO             5.693333

# %% [markdown]
# Dentro dos meses de julho e agosto esses foram os estados com a maior média de valor de revenda em Gasolina Aditivada do Brasil:

# %%
gasolina_aditivada = brasil_micro.loc['GASOLINA ADITIVADA'] 
gasolina_aditivada.groupby(['ESTADO', 'PRODUTO'])[['PREÇO MÉDIO REVENDA']].mean().sort_values(['PREÇO MÉDIO REVENDA'], ascending = False).head()
# Out:
#                              PREÇO MÉDIO REVENDA
# ESTADO   PRODUTO
# ACRE     GASOLINA ADITIVADA             6.500000
# CEARA    GASOLINA ADITIVADA             6.408462
# PIAUI    GASOLINA ADITIVADA             6.397500
# AMAZONAS GASOLINA ADITIVADA             6.343750
# PARA     GASOLINA ADITIVADA             6.271250

# %% [markdown]
# **Pergunta 4: Qual o preço médio da gasolina e do etanol por estado?**

# %%
brasil_micro.groupby(['ESTADO', 'PRODUTO'])[['PREÇO MÉDIO REVENDA']].mean()
# Out:
#                               PREÇO MÉDIO REVENDA
# ESTADO    PRODUTO
# ACRE      ETANOL HIDRATADO                 5.6675
#           GASOLINA ADITIVADA               6.5000
#           GASOLINA COMUM                   6.4450
# ALAGOAS   ETANOL HIDRATADO                 5.3760
#           GASOLINA ADITIVADA               6.2230
# ...                                           ...
# SERGIPE   GASOLINA ADITIVADA               5.7050
#           GASOLINA COMUM                   5.6150
# TOCANTINS ETANOL HIDRATADO                 5.2240
#           GASOLINA ADITIVADA               6.2500
#           GASOLINA COMUM                   6.0790
#
# [81 rows x 1 columns]

# %% [markdown]
# **Pergunta 5: Qual o município que possui o menor preço para a gasolina e para o etanol?**

# %%
# GASOLINA COMUM
gasolina_comum_cid = brasil_micro.loc["GASOLINA COMUM"]
gasolina_comum_cid.groupby(['MUNICÍPIO', 'ESTADO'])[['PREÇO MÍNIMO REVENDA']].min().sort_values(['PREÇO MÍNIMO REVENDA'], ascending = True)
# Out:
#                                          PREÇO MÍNIMO REVENDA
# MUNICÍPIO             ESTADO
# PASSO FUNDO           RIO GRANDE DO SUL                  4.13
# SUMARE                SAO PAULO                          4.15
# FRANCISCO BELTRAO     PARANA                             4.19
# SAO PAULO             SAO PAULO                          4.23
# ASSIS CHATEAUBRIAND   PARANA                             4.45
# ...                                                       ...
# CONCEICAO DO ARAGUAIA PARA                               6.19
# DELMIRO GOUVEIA       ALAGOAS                            6.25
# PARINTINS             AMAZONAS                           6.54
# CRUZEIRO DO SUL       ACRE                               6.56
# TEFE                  AMAZONAS                           6.69
#
# [459 rows x 1 columns]

# %%
# GASOLINA ADITIVADA 
gasolina_aditivada_cid = brasil_micro.loc["GASOLINA ADITIVADA"]
gasolina_aditivada_cid.groupby(['MUNICÍPIO', 'ESTADO'])[['PREÇO MÍNIMO REVENDA']].min().sort_values(['PREÇO MÍNIMO REVENDA'], ascending = True)
# Out:
#                                          PREÇO MÍNIMO REVENDA
# MUNICÍPIO             ESTADO
# PASSO FUNDO           RIO GRANDE DO SUL                  4.13
# FRANCISCO BELTRAO     PARANA                             4.29
# MARILIA               SAO PAULO                          4.47
# OLINDA                PERNAMBUCO                         4.49
# HORTOLANDIA           SAO PAULO                          4.49
# ...                                                       ...
# CONCEICAO DO ARAGUAIA PARA                               6.21
# ITAPERUNA             RIO DE JANEIRO                     6.24
# DELMIRO GOUVEIA       ALAGOAS                            6.25
# CRUZEIRO DO SUL       ACRE                               6.59
# PARINTINS             AMAZONAS                           6.59
#
# [458 rows x 1 columns]

# %%
# ETANOL
etanol_cid = brasil_micro.loc["ETANOL HIDRATADO"]
etanol_cid.groupby(['MUNICÍPIO', 'ESTADO'])[['PREÇO MÍNIMO REVENDA']].min().sort_values(['PREÇO MÍNIMO REVENDA'], ascending = True)
# Out:
#                                        PREÇO MÍNIMO REVENDA
# MUNICÍPIO           ESTADO
# PRESIDENTE PRUDENTE SAO PAULO                          2.89
# JOSE BONIFACIO      SAO PAULO                          2.94
# ARACATUBA           SAO PAULO                          2.95
# MARILIA             SAO PAULO                          2.97
# SAO PAULO           SAO PAULO                          2.98
# ...                                                     ...
# BAGE                RIO GRANDE DO SUL                  5.69
# CRUZEIRO DO SUL     ACRE                               5.69
# SANTANA             AMAPA                              5.69
# DELMIRO GOUVEIA     ALAGOAS                            5.96
# URUGUAIANA          RIO GRANDE DO SUL                  6.19
#
# [453 rows x 1 columns]

# %% [markdown]
# **Pergunta 6: Qual o município que possui o maior preço para a gasolina e para o etanol?**

# %%
#GASOLINA COMUM

gasolina_comum_cid = brasil_micro.loc["GASOLINA COMUM"]
gasolina_comum_cid.groupby(['MUNICÍPIO','ESTADO'])[['PREÇO MÁXIMO REVENDA']].max().sort_values(['PREÇO MÁXIMO REVENDA'], ascending = False)
# Out:
#                                 PREÇO MÁXIMO REVENDA
# MUNICÍPIO         ESTADO
# GURUPI            TOCANTINS                     8.75
# CRATEUS           CEARA                         8.52
# IRECE             BAHIA                         8.22
# DELMIRO GOUVEIA   ALAGOAS                       8.21
# TEFE              AMAZONAS                      8.15
# ...                                              ...
# ITAUNA            MINAS GERAIS                  5.89
# JACAREI           SAO PAULO                     5.87
# CRUZEIRO          SAO PAULO                     5.79
# FRANCISCO BELTRAO PARANA                        5.69
# SANTANA           AMAPA                         5.59
#
# [459 rows x 1 columns]

# %%
# GASOLINA ADITIVADA

gasolina_aditivada_cid = brasil_micro.loc["GASOLINA ADITIVADA"]
gasolina_aditivada_cid.groupby(['MUNICÍPIO','ESTADO'])[['PREÇO MÁXIMO REVENDA']].max().sort_values(['PREÇO MÁXIMO REVENDA'], ascending = False)
# Out:
#                                 PREÇO MÁXIMO REVENDA
# MUNICÍPIO       ESTADO
# MAGE            RIO DE JANEIRO                  9.28
# JAGUAQUARA      BAHIA                           8.82
# CRATEUS         CEARA                           8.63
# DELMIRO GOUVEIA ALAGOAS                         8.50
# BRUMADO         BAHIA                           8.45
# ...                                              ...
# PINDAMONHANGABA SAO PAULO                       5.99
# CRUZEIRO        SAO PAULO                       5.99
# IBITINGA        SAO PAULO                       5.99
# DRACENA         SAO PAULO                       5.99
# SANTANA         AMAPA                           5.53
#
# [458 rows x 1 columns]

# %%
#ETANOL

etanol_cid.groupby(['MUNICÍPIO','ESTADO'])[['PREÇO MÁXIMO REVENDA']].max().sort_values(['PREÇO MÁXIMO REVENDA'], ascending = False)
# Out:
#                                          PREÇO MÁXIMO REVENDA
# MUNICÍPIO             ESTADO
# BAGE                  RIO GRANDE DO SUL                  7.89
# TRES RIOS             RIO DE JANEIRO                     7.65
# CONCEICAO DO ARAGUAIA PARA                               7.50
# CRUZ ALTA             RIO GRANDE DO SUL                  7.45
# JANAUBA               MINAS GERAIS                       7.36
# ...                                                       ...
# FRANCA                SAO PAULO                          4.03
# DRACENA               SAO PAULO                          3.99
# VARZEA GRANDE         MATO GROSSO                        3.99
# SAO JOSE DO RIO PRETO SAO PAULO                          3.99
# GARCA                 SAO PAULO                          3.99
#
# [453 rows x 1 columns]

# %% [markdown]
# **Pergunta 7: Qual a região que possui o maior valor médio da gasolina?**

# %%
# 7.a) GASOLINA COMUM

gasolina_comum = brasil_micro.loc["GASOLINA COMUM"] 
gasolina_comum.groupby('REGIÃO')[['PREÇO MÉDIO REVENDA']].max().sort_values(['PREÇO MÉDIO REVENDA'], ascending = False)
# Out:
#               PREÇO MÉDIO REVENDA
# REGIÃO
# NORTE                        7.73
# NORDESTE                     7.49
# SUDESTE                      6.83
# SUL                          6.65
# CENTRO OESTE                 6.45

# %%
#Gráfico de colunas, testando

plt.bar(['Norte'],[7.73],
label ="Norte", color='blue', width=.5)
plt.bar(["Nordeste"],[7.49],
label ="Nordeste", color='red', width=.5)
plt.bar(["Sudeste"],[6.83],
label ="Sudeste", color='purple', width=.5)
plt.bar(["Sul"],[6.65],
label ="Sul", color='green', width=.5)
plt.bar(["Centro Oeste"],[6.45],
label ="Centro Oeste", color='orange', width=.5)
plt.xlabel('Regiões')
plt.ylabel('Preço em R$')
plt.title('Maior preço médio - gasolina comum entre jul-ago/2022')
plt.show()

# %%
# 7.b) GASOLINA ADITIVADA

gasolina_aditivada = brasil_micro.loc["GASOLINA ADITIVADA"]
gasolina_aditivada.groupby('REGIÃO')[['PREÇO MÉDIO REVENDA']].max().sort_values(['PREÇO MÉDIO REVENDA'], ascending = False)
# Out:
#               PREÇO MÉDIO REVENDA
# REGIÃO
# NORDESTE                     7.69
# NORTE                        7.30
# SUDESTE                      6.95
# SUL                          6.79
# CENTRO OESTE                 6.77

# %% [markdown]
# Pergunta 8: Qual a região que possui o menor valor médio do etanol?

# %%
# 7.c) ETANOL

etanol = brasil_micro.loc["ETANOL HIDRATADO"]
etanol.groupby('REGIÃO')[['PREÇO MÉDIO REVENDA']].min().sort_values(['PREÇO MÉDIO REVENDA'], ascending = True)
# Out:
#               PREÇO MÉDIO REVENDA
# REGIÃO
# SUDESTE                      3.36
# CENTRO OESTE                 3.44
# SUL                          3.78
# NORDESTE                     4.41
# NORTE                        4.71

# %% [markdown]
# **Pergunta 9: Há alguma correlação entre o valor do combustível (gasolina e etanol) e a região onde ele é vendido?**

# %%
#1 - Fazer uma cópia dos dataframe originais
#2 - Colocar valores numéricos para as regiões: NORTE = 1, NORDESTE = 2, CENTRO-OESTE = 3, SUDESTE = 4, SUL = 5
#3 - Colocar valores numéricos para os estados:
# - Colocar valores numéricos para os municípios?
#3 - Calcular a correlação: nome_df.corr()

copia = brasil_micro.copy()

# %%
#Valores numéricos para a coluna 'REGIÃO':

nova_regiao = {'NORTE': 1, 'NORDESTE': 2, 'CENTRO OESTE': 3, 'SUDESTE': 4, 'SUL': 5}
copia['REGIÃO'] = copia['REGIÃO'].map(nova_regiao)



#Visualizando novo dataframe
# copia_etanol = copia.loc["ETANOL HIDRATADO"]

# %%
#Valores numéricos para a coluna 'ESTADO':

novo_estado = {'ACRE': 1, 'AMAPA': 2, 'AMAZONAS': 3, 'PARA': 4, 'RONDONIA': 5, 'RORAIMA': 6, 'TOCANTINS': 7,
               'ALAGOAS': 8, 'BAHIA': 9, 'CEARA': 10, 'MARANHAO': 11, 'PARAIBA': 12, 'PERNAMBUCO': 13, 'PIAUI': 14, 'RIO GRANDE DO NORTE': 15, 'SERGIPE': 16,
               'DISTRITO FEDERAL': 17, 'GOIAS': 18, 'MATO GROSSO': 19, 'MATO GROSSO DO SUL': 20, 'ESPIRITO SANTO': 21, 'MINAS GERAIS': 22, 'RIO DE JANEIRO': 23, 'SAO PAULO': 24,
                'PARANA': 25, 'SANTA CATARINA': 26, 'RIO GRANDE DO SUL': 27}
copia['ESTADO'] = copia['ESTADO'].map(novo_estado)

# %%
regiao_norte = copia.query('REGIÃO == 1')
regiao_norte
# Out:
#                       MÊS  REGIÃO  ESTADO   MUNICÍPIO  \
# PRODUTO
# ETANOL HIDRATADO  jul.-22       1       4  ABAETETUBA
# ETANOL HIDRATADO  jul.-22       1       4  ANANINDEUA
# ETANOL HIDRATADO  jul.-22       1       7   ARAGUAINA
# ETANOL HIDRATADO  jul.-22       1       5   ARIQUEMES
# ETANOL HIDRATADO  jul.-22       1       4       BELEM
# ...                   ...     ...     ...         ...
# GASOLINA COMUM    ago.-22       1       2     SANTANA
# GASOLINA COMUM    ago.-22       1       4    SANTAREM
# GASOLINA COMUM    ago.-22       1       3        TEFE
# GASOLINA COMUM    ago.-22       1       5     VILHENA
# GASOLINA COMUM    ago.-22       1       4    XINGUARA
#
#                   NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# PRODUTO
# ETANOL HIDRATADO                             4                 5.84
# ETANOL HIDRATADO                            16                 5.54
# ETANOL HIDRATADO                             7                 5.44
# ETANOL HIDRATADO                            25                 6.01
# ETANOL HIDRATADO                            65                 5.80
# ...                                        ...                  ...
# GASOLINA COMUM                              24                 5.05
# GASOLINA COMUM                              60                 5.33
# GASOLINA COMUM                              31                 6.84
# GASOLINA COMUM                              40                 5.78
# GASOLINA COMUM                              40                 6.36
#
#                   DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# PRODUTO
# ETANOL HIDRATADO                  0.266                  5.49
# ETANOL HIDRATADO                  0.689                  4.98
# ETANOL HIDRATADO                  0.155                  5.19
# ETANOL HIDRATADO                  0.475                  5.19
# ETANOL HIDRATADO                  0.395                  5.09
# ...                                 ...                   ...
# GASOLINA COMUM                    0.193                  4.75
# GASOLINA COMUM                    0.214                  4.87
# GASOLINA COMUM                    0.131                  6.69
# GASOLINA COMUM                    0.186                  5.57
# GASOLINA COMUM                    0.141                  6.13
#
#                   PREÇO MÁXIMO REVENDA  COEF DE VARIAÇÃO REVENDA
# PRODUTO
# ETANOL HIDRATADO                  6.09                     0.046
# ETANOL HIDRATADO                  6.79                     0.124
# ETANOL HIDRATADO                  5.65                     0.029
# ETANOL HIDRATADO                  6.89                     0.079
# ETANOL HIDRATADO                  6.74                     0.068
# ...                                ...                       ...
# GASOLINA COMUM                    5.39                     0.038
# GASOLINA COMUM                    5.79                     0.040
# GASOLINA COMUM                    7.00                     0.019
# GASOLINA COMUM                    6.65                     0.032
# GASOLINA COMUM                    6.57                     0.022
#
# [206 rows x 10 columns]

# %%
# ETANOL 

copia_etanol = copia.loc["ETANOL HIDRATADO"]
copia_etanol
# Out:
#                       MÊS  REGIÃO  ESTADO              MUNICÍPIO  \
# PRODUTO
# ETANOL HIDRATADO  jul.-22       1       4             ABAETETUBA
# ETANOL HIDRATADO  jul.-22       2      11             ACAILANDIA
# ETANOL HIDRATADO  jul.-22       4      24             ADAMANTINA
# ETANOL HIDRATADO  jul.-22       3      18  AGUAS LINDAS DE GOIAS
# ETANOL HIDRATADO  jul.-22       2       9             ALAGOINHAS
# ...                   ...     ...     ...                    ...
# ETANOL HIDRATADO  ago.-22       4      23          VOLTA REDONDA
# ETANOL HIDRATADO  ago.-22       4      24             VOTORANTIM
# ETANOL HIDRATADO  ago.-22       4      24            VOTUPORANGA
# ETANOL HIDRATADO  ago.-22       5      26                XANXERE
# ETANOL HIDRATADO  ago.-22       1       4               XINGUARA
#
#                   NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# PRODUTO
# ETANOL HIDRATADO                             4                 5.84
# ETANOL HIDRATADO                            17                 5.87
# ETANOL HIDRATADO                            24                 3.97
# ETANOL HIDRATADO                            18                 4.36
# ETANOL HIDRATADO                            36                 5.38
# ...                                        ...                  ...
# ETANOL HIDRATADO                            51                 4.86
# ETANOL HIDRATADO                            50                 3.61
# ETANOL HIDRATADO                            60                 3.44
# ETANOL HIDRATADO                             8                 5.37
# ETANOL HIDRATADO                            21                 6.05
#
#                   DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# PRODUTO
# ETANOL HIDRATADO                  0.266                  5.49
# ETANOL HIDRATADO                  0.379                  4.99
# ETANOL HIDRATADO                  0.214                  3.71
# ETANOL HIDRATADO                  0.235                  3.99
# ETANOL HIDRATADO                  0.369                  4.89
# ...                                 ...                   ...
# ETANOL HIDRATADO                  0.155                  4.54
# ETANOL HIDRATADO                  0.241                  3.15
# ETANOL HIDRATADO                  0.215                  2.99
# ETANOL HIDRATADO                  0.470                  4.79
# ETANOL HIDRATADO                  0.361                  5.59
#
#                   PREÇO MÁXIMO REVENDA  COEF DE VARIAÇÃO REVENDA
# PRODUTO
# ETANOL HIDRATADO                  6.09                     0.046
# ETANOL HIDRATADO                  6.30                     0.065
# ETANOL HIDRATADO                  4.39                     0.054
# ETANOL HIDRATADO                  4.59                     0.054
# ETANOL HIDRATADO                  5.99                     0.069
# ...                                ...                       ...
# ETANOL HIDRATADO                  5.19                     0.032
# ETANOL HIDRATADO                  4.20                     0.067
# ETANOL HIDRATADO                  3.99                     0.062
# ETANOL HIDRATADO                  5.81                     0.087
# ETANOL HIDRATADO                  6.59                     0.060
#
# [903 rows x 10 columns]

# %%
# CORRELAÇÃO ETANOL

(copia_etanol.corr())
# Out:
#                                 REGIÃO    ESTADO  \
# REGIÃO                        1.000000  0.966194
# ESTADO                        0.966194  1.000000
# NÚMERO DE POSTOS PESQUISADOS -0.008101  0.028314
# PREÇO MÉDIO REVENDA          -0.334654 -0.429280
# DESVIO PADRÃO REVENDA        -0.015512 -0.059673
# PREÇO MÍNIMO REVENDA         -0.335941 -0.429298
# PREÇO MÁXIMO REVENDA         -0.294093 -0.381038
# COEF DE VARIAÇÃO REVENDA      0.087127  0.074934
#
#                               NÚMERO DE POSTOS PESQUISADOS  \
# REGIÃO                                           -0.008101
# ESTADO                                            0.028314
# NÚMERO DE POSTOS PESQUISADOS                      1.000000
# PREÇO MÉDIO REVENDA                              -0.283172
# DESVIO PADRÃO REVENDA                            -0.085752
# PREÇO MÍNIMO REVENDA                             -0.332876
# PREÇO MÁXIMO REVENDA                             -0.156107
# COEF DE VARIAÇÃO REVENDA                          0.026065
#
#                               PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  \
# REGIÃO                                  -0.334654              -0.015512
# ESTADO                                  -0.429280              -0.059673
# NÚMERO DE POSTOS PESQUISADOS            -0.283172              -0.085752
# PREÇO MÉDIO REVENDA                      1.000000               0.464401
# DESVIO PADRÃO REVENDA                    0.464401               1.000000
# PREÇO MÍNIMO REVENDA                     0.964549               0.289001
# PREÇO MÁXIMO REVENDA                     0.927534               0.654005
# COEF DE VARIAÇÃO REVENDA                 0.149816               0.935805
#
#                               PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# REGIÃO                                   -0.335941             -0.294093
# ESTADO                                   -0.429298             -0.381038
# NÚMERO DE POSTOS PESQUISADOS             -0.332876             -0.156107
# PREÇO MÉDIO REVENDA                       0.964549              0.927534
# DESVIO PADRÃO REVENDA                     0.289001              0.654005
# PREÇO MÍNIMO REVENDA                      1.000000              0.854162
# PREÇO MÁXIMO REVENDA                      0.854162              1.000000
# COEF DE VARIAÇÃO REVENDA                 -0.033437              0.396735
#
#                               COEF DE VARIAÇÃO REVENDA
# REGIÃO                                        0.087127
# ESTADO                                        0.074934
# NÚMERO DE POSTOS PESQUISADOS                  0.026065
# PREÇO MÉDIO REVENDA                           0.149816
# DESVIO PADRÃO REVENDA                         0.935805
# PREÇO MÍNIMO REVENDA                         -0.033437
# PREÇO MÁXIMO REVENDA                          0.396735
# COEF DE VARIAÇÃO REVENDA                      1.000000

# %%
#CORRELAÇÃO

(copia.corr())
# Out:
#                                 REGIÃO    ESTADO  \
# REGIÃO                        1.000000  0.967387
# ESTADO                        0.967387  1.000000
# NÚMERO DE POSTOS PESQUISADOS  0.004830  0.026544
# PREÇO MÉDIO REVENDA          -0.252556 -0.294009
# DESVIO PADRÃO REVENDA        -0.117143 -0.125094
# PREÇO MÍNIMO REVENDA         -0.249589 -0.297924
# PREÇO MÁXIMO REVENDA         -0.224535 -0.257121
# COEF DE VARIAÇÃO REVENDA     -0.041762 -0.034877
#
#                               NÚMERO DE POSTOS PESQUISADOS  \
# REGIÃO                                            0.004830
# ESTADO                                            0.026544
# NÚMERO DE POSTOS PESQUISADOS                      1.000000
# PREÇO MÉDIO REVENDA                              -0.166104
# DESVIO PADRÃO REVENDA                            -0.023041
# PREÇO MÍNIMO REVENDA                             -0.214443
# PREÇO MÁXIMO REVENDA                             -0.035909
# COEF DE VARIAÇÃO REVENDA                          0.038241
#
#                               PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  \
# REGIÃO                                  -0.252556              -0.117143
# ESTADO                                  -0.294009              -0.125094
# NÚMERO DE POSTOS PESQUISADOS            -0.166104              -0.023041
# PREÇO MÉDIO REVENDA                      1.000000               0.436398
# DESVIO PADRÃO REVENDA                    0.436398               1.000000
# PREÇO MÍNIMO REVENDA                     0.968837               0.264749
# PREÇO MÁXIMO REVENDA                     0.923367               0.655414
# COEF DE VARIAÇÃO REVENDA                 0.142951               0.945848
#
#                               PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# REGIÃO                                   -0.249589             -0.224535
# ESTADO                                   -0.297924             -0.257121
# NÚMERO DE POSTOS PESQUISADOS             -0.214443             -0.035909
# PREÇO MÉDIO REVENDA                       0.968837              0.923367
# DESVIO PADRÃO REVENDA                     0.264749              0.655414
# PREÇO MÍNIMO REVENDA                      1.000000              0.847731
# PREÇO MÁXIMO REVENDA                      0.847731              1.000000
# COEF DE VARIAÇÃO REVENDA                 -0.036285              0.412473
#
#                               COEF DE VARIAÇÃO REVENDA
# REGIÃO                                       -0.041762
# ESTADO                                       -0.034877
# NÚMERO DE POSTOS PESQUISADOS                  0.038241
# PREÇO MÉDIO REVENDA                           0.142951
# DESVIO PADRÃO REVENDA                         0.945848
# PREÇO MÍNIMO REVENDA                         -0.036285
# PREÇO MÁXIMO REVENDA                          0.412473
# COEF DE VARIAÇÃO REVENDA                      1.000000

# %% [markdown]
# **Pergunta 10: Há alguma correlação entre o valor do combustível (gasolina e etanol) e a bandeira que vende ele?**

# %% [markdown]
# **Pergunta 11: A fazer**
#
# Através do coeficiente de variação, explique se as bases de dados utilizadas são mais ou menos homogêneas? (Para o Brasil, regiões, estados e municípios).
#
#
# PS: Há algum padrão de C.V para a indústria de combustível?

# %%
#Criando uma nova coluna com o coeficiente de variação em porcentagem (%)

brasil_micro['COEF DE VARIAÇÃO REVENDA %'] = brasil_micro['COEF DE VARIAÇÃO REVENDA'] * 100
brasil_macro[ 'COEF DE VARIAÇÃO REVENDA %'] = brasil_macro['COEF DE VARIAÇÃO REVENDA']*100

# %%
#Considerando todos os combustíveis POR REGIÃO
brasil_micro.groupby('REGIÃO')[['COEF DE VARIAÇÃO REVENDA %']].max().sort_values(['COEF DE VARIAÇÃO REVENDA %'], ascending = False)
# Out:
#               COEF DE VARIAÇÃO REVENDA %
# REGIÃO
# NORDESTE                            23.0
# SUDESTE                             15.0
# SUL                                 13.8
# NORTE                               12.4
# CENTRO OESTE                         9.6

# %%
# Etanol POR REGIÃO
etanol_var = brasil_micro.loc["ETANOL HIDRATADO"]
etanol_var.groupby('REGIÃO')[['COEF DE VARIAÇÃO REVENDA %']].max().sort_values(['COEF DE VARIAÇÃO REVENDA %'], ascending = False)
# Out:
#               COEF DE VARIAÇÃO REVENDA %
# REGIÃO
# SUL                                 13.8
# SUDESTE                             12.5
# NORTE                               12.4
# NORDESTE                             9.4
# CENTRO OESTE                         8.6

# %%
# Gasolina comum POR REGIÃO
gaso_comum_var = brasil_micro.loc["GASOLINA COMUM"]
gaso_comum_var.groupby('REGIÃO')[['COEF DE VARIAÇÃO REVENDA %']].max().sort_values(['COEF DE VARIAÇÃO REVENDA %'], ascending = False)
# Out:
#               COEF DE VARIAÇÃO REVENDA %
# REGIÃO
# NORDESTE                            11.9
# SUDESTE                             10.8
# SUL                                  9.3
# NORTE                                8.7
# CENTRO OESTE                         8.6

# %%
# Gasolina comum POR REGIÃO
gaso_adit_var = brasil_micro.loc["GASOLINA ADITIVADA"]
gaso_adit_var.groupby('REGIÃO')[['COEF DE VARIAÇÃO REVENDA %']].max().sort_values(['COEF DE VARIAÇÃO REVENDA %'], ascending = False)
# Out:
#               COEF DE VARIAÇÃO REVENDA %
# REGIÃO
# NORDESTE                            23.0
# SUDESTE                             15.0
# CENTRO OESTE                         9.6
# SUL                                  9.5
# NORTE                                9.4

# %%
#Etanol por município
etanol_var.groupby(['MUNICÍPIO', 'ESTADO'])[['COEF DE VARIAÇÃO REVENDA %']].max().sort_values(['COEF DE VARIAÇÃO REVENDA %'], ascending = False)
# Out:
#                                     COEF DE VARIAÇÃO REVENDA %
# MUNICÍPIO        ESTADO
# PASSO FUNDO      RIO GRANDE DO SUL                        13.8
# OSORIO           RIO GRANDE DO SUL                        13.8
# CRICIUMA         SANTA CATARINA                           13.6
# SANTA MARIA      RIO GRANDE DO SUL                        13.2
# SAO LUIZ GONZAGA RIO GRANDE DO SUL                        13.1
# ...                                                        ...
# ICO              CEARA                                     2.2
# ARCOVERDE        PERNAMBUCO                                1.8
# PINHEIRO         MARANHAO                                  0.0
# SANTANA          AMAPA                                     0.0
# PARAGOMINAS      PARA                                      0.0
#
# [453 rows x 1 columns]

# %%
#Gasolina comum por município
gaso_comum_var.groupby(['MUNICÍPIO', 'ESTADO'])[['COEF DE VARIAÇÃO REVENDA %']].max().sort_values(['COEF DE VARIAÇÃO REVENDA %'], ascending = False)
plt.plot(['MUNICÍPIO'], ['COEF DE VARIAÇÃO REVENDA %'])

plt.show()

# %%
#Gasolina comum por município
gaso_adit_var.groupby(['MUNICÍPIO', 'ESTADO'])[['COEF DE VARIAÇÃO REVENDA %']].max().sort_values(['COEF DE VARIAÇÃO REVENDA %'], ascending = False)
# Out:
#                            COEF DE VARIAÇÃO REVENDA %
# MUNICÍPIO  ESTADO
# JAGUAQUARA BAHIA                                 23.0
# ADAMANTINA SAO PAULO                             15.0
# PASSOS     MINAS GERAIS                          15.0
# MAGE       RIO DE JANEIRO                        14.0
# BRUMADO    BAHIA                                 12.0
# ...                                               ...
# CIANORTE   PARANA                                 2.5
# ITAPERUNA  RIO DE JANEIRO                         2.3
# ICO        CEARA                                  2.3
# DRACENA    SAO PAULO                              2.2
# POCOES     BAHIA                                  0.0
#
# [458 rows x 1 columns]

# %% [markdown]
# **Pergunta 12: A fazer** * correlação postos (quantidade) e a variação nos dados

# %% [markdown]
# Pergunta 13:  Fazer uma comparaçao entre salário minimo brasil x preço combustivel
# e salário minimo mundial x preço combustivel das 10 maiores potencias mundiais

# %% [markdown]
# Pergunta 14: Variação do preço médio dos combustíveis ao longo de 2022
